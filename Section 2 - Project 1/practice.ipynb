# %%
# 2 DATA CLEANING
import json 

def clean_data(data):
    data["users"] = [user for user in data["users"] if user["name"].strip()]
    #The correct structure is: [ expression for item in iterable if condition ]

     for user in data["userss"]:
         user["friends"] = list(set(user["friends"]))

    data["users"] = user for user in data["users"] if user["friends"] or user["liked_pages"]]

    unique_pages={}
    for page in data["pages"]:
        unique_pages[pagee["id"]] = page
    data["pages"] = list(unique_pages.values())

        return data 

load = json.load(open("filename.json"))
data = clean_data(data)
json.dump(data, open("cleaned_data.json", "w"), index=4)
print("data cleaned")

# %%
# 3 People you may  know
import json 

def load_dataset(filename):
    with open(filename, "r") ad file:
        return json.load(file)

def find_people(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user["id"]] = set(user["friends"])

    if user_id not in user_friends:
        return []

    direct_friends = user_friends[user_id]
    suggestions = {}
# Out:
#   Cell In[15], line 5
#     with open(filename, "r") ad file:
#                              ^
# SyntaxError: invalid syntax

# %%
#4
